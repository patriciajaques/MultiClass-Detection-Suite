# %% [markdown]
# # Detecção de Comportamentos de Aprendizagem
#
# Este notebook executa a detecção de comportamentos de aprendizagem usando logs de um Sistema Tutor Inteligente.

# %%
import sklearn
print(f"Versão do scikit-learn: {sklearn.__version__}")
import optuna
print(f"Versão do optuna: {optuna.__version__}")
# Out:
# Versão do scikit-learn: 1.1.3
# Versão do optuna: 4.0.0

# %%
# Célula 1 - Configuração do ambiente
import os
from pathlib import Path
import sys

def setup_environment():
    """Configura o ambiente de execução e adiciona src ao PYTHONPATH"""
    try:
        # Verifica se está no Colab
        from google.colab import drive
        drive.mount('/content/drive')
        base_path = Path('/content/drive/MyDrive/Colab Notebooks/behavior-detection')
        print("Executando no Google Colab")
    except ImportError:
        # Execução local
        # Encontra o diretório raiz do projeto
        current_dir = Path.cwd()
        print(f"Current dir: {current_dir}")
        # Se estiver no diretório notebooks, sobe um nível
        if current_dir.name == 'notebooks':
            base_path = current_dir.parent.parent
        else:
            base_path = current_dir
            
        # Verifica se encontrou o diretório correto
        if base_path.name != 'behavior-detection':
            raise RuntimeError("Não foi possível encontrar o diretório raiz do projeto 'behavior-detection'")
        print("Executando localmente")
    
    # Adiciona src ao Python path
    src_path = str(base_path / 'src')
    if src_path not in sys.path:
        sys.path.insert(0, src_path)
    
    return base_path

# Configura o ambiente
base_path = setup_environment()
print(f"Diretório base: {base_path}")
print(f"Python path: {sys.path}")
# Out:
# Current dir: /Users/patricia/Documents/code/python-code/behavior-detection/src/notebooks
# Executando localmente
# Diretório base: /Users/patricia/Documents/code/python-code/behavior-detection
# Python path: ['/Users/patricia/Documents/code/python-code/behavior-detection/src', '/Users/patricia/Documents/code/python-code/behavior-detection/src/notebooks', '/Users/patricia/Documents/code/python-code/behavior-detection/src/notebooks/src', '/Users/patricia/Documents/code/python-code/behavior-detection/src/notebooks/notebooks', '/Users/patricia/Documents/code/python-code/behavior-detection/src/notebooks/tests', '/opt/anaconda3/envs/projetos_ML/lib/python311.zip', '/opt/anaconda3/envs/projetos_ML/lib/python3.11', '/opt/anaconda3/envs/projetos_ML/lib/python3.11/lib-dynload', '', '/opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages', '/opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/setuptools/_vendor']

# %%
from behavior.behavior_detection import (
    setup_project_path,
    load_and_preprocess_data,
    prepare_data,
    train_models
)

# Configurar caminhos
base_path = Path('/content/drive/MyDrive/Colab Notebooks/behavior-detection')
paths = setup_project_path(base_path)

# Carregar e pré-processar dados
data = load_and_preprocess_data(paths)
print(f"Shape dos dados: {data.shape}")

# Preparar dados para treinamento
X_train, X_test, y_train, y_test = prepare_data(data)
print(f"\nShapes após preparação:")
print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")

# Treinar modelos
train_models(X_train, X_test, y_train, y_test, paths)
# Out:
# Executando localmente
# Shape dos dados: (1097, 372)
# Entrada fit - Shape: (902, 370)
# Fit realizado com sucesso
# Colunas numéricas: 366
# Colunas nominais: 206
# Entrada transform - Shape: (902, 370)
# Saída transform - Shape: (902, 532)
# Entrada transform - Shape: (195, 370)
# Saída transform - Shape: (195, 532)
#
# Shapes após preparação:
# X_train: (902, 532)
# X_test: (195, 532)
# /opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:188: UserWarning: Found unknown categories in columns [52, 55, 58, 68, 74, 79, 81, 95, 114, 143, 159, 170, 171, 175, 176] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 2024-12-06 17:26:38,350 | optuna_training | INFO | Training and evaluating Logistic Regression with Optuna Optimization and none
# INFO:optuna_training:Training and evaluating Logistic Regression with Optuna Optimization and none
# Verificando progresso anterior...
# Nenhum stage completado anteriormente. Iniciando do começo.
#
# ==================================================
# Iniciando Stage 1: etapa1
# ==================================================
# Executando etapa: etapa1
# Modelos: ['Logistic Regression', 'Decision Tree']
# Seletores: ['none', 'pca', 'rfe', 'rf', 'mi']
# Iniciando treinamento da etapa etapa1...
# Inside OptunaBayesianOptimizationTraining.optimize_model
# 2024-12-06 17:27:00,575 | optuna_training | INFO | Best parameters: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}
# INFO:optuna_training:Best parameters: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}
# 2024-12-06 17:27:00,577 | optuna_training | INFO | Best cross-validation score: 1.0
# INFO:optuna_training:Best cross-validation score: 1.0
# 2024-12-06 17:27:00,579 | optuna_training | INFO | All hyperparameter combinations and their cross-validation results:
# INFO:optuna_training:All hyperparameter combinations and their cross-validation results:
# 2024-12-06 17:27:00,584 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,586 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,590 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 0.991777972027972
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 0.991777972027972
# 2024-12-06 17:27:00,593 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 0.991777972027972
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 0.991777972027972
# 2024-12-06 17:27:00,594 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,595 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,597 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,599 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,603 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 0.991777972027972
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 0.991777972027972
# 2024-12-06 17:27:00,604 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,606 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,607 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,608 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,610 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,611 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,612 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,616 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,620 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,621 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,622 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,624 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,626 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,627 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,629 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,630 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,631 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,632 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 0.991777972027972
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 0.991777972027972
# 2024-12-06 17:27:00,635 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,637 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,638 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 0.991777972027972
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 0.991777972027972
# 2024-12-06 17:27:00,639 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,640 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,642 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,643 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,644 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,645 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 0.991777972027972
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 0.991777972027972
# 2024-12-06 17:27:00,648 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,652 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,654 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,655 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,656 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 0.991777972027972
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 0.991777972027972
# 2024-12-06 17:27:00,682 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,685 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,687 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,688 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,690 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,691 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,692 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.1, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,694 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,695 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced'}, Mean Test Score: 1.0
# 2024-12-06 17:27:00,697 | optuna_training | INFO | Number of tests that resulted in NaN for Logistic Regression: 0
# INFO:optuna_training:Number of tests that resulted in NaN for Logistic Regression: 0
# 2024-12-06 17:27:00,698 | optuna_training | INFO | Optuna Optimization Best Result for Logistic Regression with none: 1.0
# INFO:optuna_training:Optuna Optimization Best Result for Logistic Regression with none: 1.0
# 2024-12-06 17:27:00,700 | optuna_training | INFO | Training and evaluating Logistic Regression with Optuna Optimization and pca
# INFO:optuna_training:Training and evaluating Logistic Regression with Optuna Optimization and pca
# Inside OptunaBayesianOptimizationTraining.optimize_model
# 2024-12-06 17:27:22,796 | optuna_training | INFO | Best parameters: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.9882730077972145}
# INFO:optuna_training:Best parameters: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.9882730077972145}
# 2024-12-06 17:27:22,798 | optuna_training | INFO | Best cross-validation score: 1.0
# INFO:optuna_training:Best cross-validation score: 1.0
# 2024-12-06 17:27:22,799 | optuna_training | INFO | All hyperparameter combinations and their cross-validation results:
# INFO:optuna_training:All hyperparameter combinations and their cross-validation results:
# 2024-12-06 17:27:22,802 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.819873765705627}, Mean Test Score: 0.9307705784781257
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.819873765705627}, Mean Test Score: 0.9307705784781257
# 2024-12-06 17:27:22,804 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 10.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.
| optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.9882730077972145}, Mean Test Score: 1.0
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.9882730077972145}, Mean Test Score: 1.0
# 2024-12-06 17:27:22,828 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.9188354569151446}, Mean Test Score: 0.9536337970205894
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.9188354569151446}, Mean Test Score: 0.9536337970205894
# 2024-12-06 17:27:22,828 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.9558030213212055}, Mean Test Score: 0.9800723443223444
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.9558030213212055}, Mean Test Score: 0.9800723443223444
# 2024-12-06 17:27:22,830 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.9662853147063875}, Mean Test Score: 0.9813223443223442
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.9662853147063875}, Mean Test Score: 0.9813223443223442
# 2024-12-06 17:27:22,830 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.8715426465844757}, Mean Test Score: 0.9463444338680189
# ...
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'newton-cg', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.955038588654354}, Mean Test Score: 0.9800723443223444
# 2024-12-06 17:27:22,862 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.9801745365146195}, Mean Test Score: 0.9927582417582418
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.9801745365146195}, Mean Test Score: 0.9927582417582418
# 2024-12-06 17:27:22,867 | optuna_training | INFO | Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.9140498963534133}, Mean Test Score: 0.9587331285067136
# INFO:optuna_training:Params: {'classifier__penalty': 'l2', 'classifier__C': 0.01, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_components': 0.9140498963534133}, Mean Test Score: 0.9587331285067136
# 2024-12-06 17:27:22,868 | optuna_training | INFO | Number of tests that resulted in NaN for Logistic Regression: 0
# INFO:optuna_training:Number of tests that resulted in NaN for Logistic Regression: 0
# 2024-12-06 17:27:22,869 | optuna_training | INFO | Optuna Optimization Best Result for Logistic Regression with pca: 1.0
# INFO:optuna_training:Optuna Optimization Best Result for Logistic Regression with pca: 1.0
# 2024-12-06 17:27:22,869 | optuna_training | INFO | Training and evaluating Logistic Regression with Optuna Optimization and rfe
# INFO:optuna_training:Training and evaluating Logistic Regression with Optuna Optimization and rfe
# Inside OptunaBayesianOptimizationTraining.optimize_model
# [W 2024-12-06 17:27:24,280] Trial 0 failed with parameters: {'classifier__penalty': 'l2', 'classifier__C': 1.0, 'classifier__solver': 'lbfgs', 'classifier__max_iter': 5000, 'classifier__multi_class': 'multinomial', 'classifier__class_weight': 'balanced', 'feature_selection__n_features_to_select': 19} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/Users/patricia/Documents/code/python-code/behavior-detection/src/core/training/optuna_bayesian_optimization_training.py", line 36, in objective
#     return cross_val_score(
#            ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 515, in cross_val_score
#     cv_results = cross_validate(
#                  ^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 266, in cross_validate
#     results = parallel(
#               ^^^^^^^^^
#   File "/opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/joblib/parallel.py", line 2007, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/joblib/parallel.py", line 1650, in _get_outputs
#     yield from self._retrieve()
#   File "/opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/joblib/parallel.py", line 1762, in _retrieve
#     time.sleep(0.01)
# KeyboardInterrupt
# [W 2024-12-06 17:27:24,283] Trial 0 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 23
#      20 print(f"X_test: {X_test.shape}")
#      22 # Treinar modelos
# ---> 23 train_models(X_train, X_test, y_train, y_test, paths)
#
# File ~/Documents/code/python-code/behavior-detection/src/behavior/behavior_detection.py:129, in train_models(X_train, X_test, y_train, y_test, paths)
#     127 # Executar treinamento
#     128 try:
# --> 129     training_manager.execute_all_stages(training_manager, stages)
#     131     # Gerar relatórios finais
#     132     from core.reporting import metrics_reporter
#
# File ~/Documents/code/python-code/behavior-detection/src/core/management/stage_training_manager.py:159, in StageTrainingManager.execute_all_stages(self, training_manager, stages)
#     156 training_manager._save_progress(list(completed_stages), stage_name)
#     158 # Executar stage
# --> 159 results = training_manager.execute_stage(stage_name, models, selectors)
#     161 if results:
#     162     trained_models, class_metrics, avg_metrics = results
#
# File ~/Documents/code/python-code/behavior-detection/src/core/management/stage_training_manager.py:95, in StageTrainingManager.execute_stage(self, stage_name, models, selectors)
#      93 if checkpoint is None:
#      94     print(f"Iniciando treinamento da etapa {stage_name}...")
# ---> 95     trained_models, class_metrics, avg_metrics = self.train_models(models, selectors)
#      96     self.save_stage_results(trained_models, class_metrics, avg_metrics, stage_name)
#      97     print(f"Etapa {stage_name} concluída e resultados salvos.")
#
# File ~/Documents/code/python-code/behavior-detection/src/core/management/stage_training_manager.py:54, in StageTrainingManager.train_models(self, selected_models, selected_selectors)
#      52 """Executa o treinamento dos modelos selecionados."""
#      53 training = OptunaBayesianOptimizationTraining()
# ---> 54 trained_models = training.train_model(
#      55     X_train=self.X_train,
#      56     y_train=self.y_train,
#      57     model_params=self.model_params,
#      58     selected_models=selected_models,
#      59     selected_selectors=selected_selectors,
#      60     n_iter=self.n_iter,
#      61     cv=self.cv,
#      62     scoring=self.scoring,
#      63     n_jobs=self.n_jobs
#      64 )
#      66 class_metrics, avg_metrics = metrics_reporter.evaluate_models(
#      67     trained_models, self.X_train, self.y_train,
#      68     self.X_test, self.y_test
#      69 )
#      71 return trained_models, class_metrics, avg_metrics
#
# File ~/Documents/code/python-code/behavior-detection/src/core/training/base_training.py:55, in BaseTraining.train_model(self, X_train, y_train, model_params, selected_models, selected_selectors, n_iter, cv, scoring, n_jobs)
#      52             # Obter o espaço de busca diretamente do selector_instance
#      53             selector_search_space = selector_instance.get_search_space()
# ---> 55         self.optimize_model(
#      56             pipeline=pipeline,
#      57             model_name=model_name,
#      58             model_params=model_params,
#      59             selector_name=selector_name,
#      60             X_train=X_train,
#      61             y_train=y_train,
#      62             n_iter=n_iter,
#      63             cv=cv,
#      64             scoring=scoring,
#      65             n_jobs=n_jobs,
#      66             selector_search_space=selector_search_space
#      67         )
#      69 self.total_execution_time = time() - start_time
#      70 self._log_execution_time(len(models))
#
# File ~/Documents/code/python-code/behavior-detection/src/core/training/optuna_bayesian_optimization_training.py:54, in OptunaBayesianOptimizationTraining.optimize_model(self, pipeline, model_name, model_params, selector_name, X_train, y_train, n_iter, cv, scoring, n_jobs, selector_search_space)
#      52 # Iniciar o tempo de otimização
#      53 start_time = time()
# ---> 54 study.optimize(objective, n_trials=n_iter)
#      55 total_time = time() - start_time
#      57 # Criar uma cópia do pipeline para o treinamento final
#
# File /opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/optuna/study/study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File /opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File /opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File /opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/optuna/study/_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File /opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/optuna/study/_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# File ~/Documents/code/python-code/behavior-detection/src/core/training/optuna_bayesian_optimization_training.py:36, in OptunaBayesianOptimizationTraining.optimize_model.<locals>.objective(trial)
#      33     hyperparams = {**model_hyperparams, **selector_hyperparams}
#      34     pipeline.set_params(**hyperparams)
# ---> 36     return cross_val_score(
#      37         estimator=pipeline,
#      38         X=X_train,
#      39         y=y_train,
#      40         scoring=scoring,
#      41         cv=cv,
#      42         n_jobs=n_jobs
#      43     ).mean()
#      45 except Exception as e:
#      46     self.log_parameter_error(self.logger, model_name, hyperparams)
#
# File /opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:515, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     512 # To ensure multimetric format is not supported
#     513 scorer = check_scoring(estimator, scoring=scoring)
# --> 515 cv_results = cross_validate(
#     516     estimator=estimator,
#     517     X=X,
#     518     y=y,
#     519     groups=groups,
#     520     scoring={"score": scorer},
#     521     cv=cv,
#     522     n_jobs=n_jobs,
#     523     verbose=verbose,
#     524     fit_params=fit_params,
#     525     pre_dispatch=pre_dispatch,
#     526     error_score=error_score,
#     527 )
#     528 return cv_results["test_score"]
#
# File /opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:266, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     263 # We clone the estimator to make sure that all the folds are
#     264 # independent, and that it is pickle-able.
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#     269         X,
#     270         y,
#     271         scorers,
#     272         train,
#     273         test,
#     274         verbose,
#     275         None,
#     276         fit_params,
#     277         return_train_score=return_train_score,
#     278         return_times=True,
#     279         return_estimator=return_estimator,
#     280         error_score=error_score,
#     281     )
#     282     for train, test in cv.split(X, y, groups)
#     283 )
#     285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#
# File /opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /opt/anaconda3/envs/projetos_ML/lib/python3.11/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:
